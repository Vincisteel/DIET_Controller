# %%
from typing import Dict, List, Tuple
import torch
import numpy as np
import pandas as pd
import gym
import torch
import torch.nn as nn

import json
from plotly.subplots import make_subplots
from agent.DQN_Agent import DQNAgent
from agent.DDPG_Agent import DDPG_Agent
from agent.SpinUp_DDPG import DDPGSpinUp
from Logger import Logger
from environment.ContinuousEnvironment import ContinuousSimpleEnvironment

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set environment and agent parameters

# %%
env = ContinuousSimpleEnvironment(param_list=['Tair', 'RH', 'Tmrt', 'Tout', 'Qheat', 'Occ'],
alpha=0.5,
beta=1,
min_temp=16,
max_temp=21,
modelname='CELLS_v1.fmu',
simulation_path=r'C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\EnergyPlus_simulations\simple_simulation',
days=151,
hours=24,
minutes=60,
seconds=60,
ep_timestep=6)

#old_ddpg_agent_arguments = {
#"discount": [0.99],
#"batch_size": [128],
#"tau": [0.05],
#"policy_noise": [0.2],
#"noise_clip":[0.5],
#"lr":[1e-3],
#"num_random_episodes":[1],
#"num_training_iterations":[1000],
#"seed": [778]
#}


agent_arguments = {
"memory_size": [1000],
"batch_size": [256],
"actor_update":[10],
"target_update": [100],
"epsilon_decay": [1 / 20000],
"max_epsilon": [1.2],
"min_epsilon":  [0.1],
"lr":[1e-3],
"gamma": [0.99],
"polyak": [0.995],
"inside_dim": [256],
"num_hidden_layers": [4],
"seed": [788]
}

# %%
def cumulative_reward(data:pd.DataFrame) -> float:
    return np.cumsum(np.array(data["Reward"]))[-1]

# %%
agent = DDPG_Agent(env).from_dict(dict_arguments=curr_agent_arguments)

agent.load(directory=r'C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\logs\simple_simulation\results\DDPG_Agent\2022_6_6\results_2022_6_6_17_41\model_weights', 
filename='torch_ep_2')

nn = agent.actor
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\src\DDPG_notebook.ipynb Cell 5' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000004?line=0'>1</a> agent = DDPG_Agent(env).from_dict(dict_arguments=curr_agent_arguments)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000004?line=2'>3</a> agent.load(directory=r'C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\logs\simple_simulation\results\DDPG_Agent\2022_6_6\results_2022_6_6_17_41\model_weights',
#       <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000004?line=3'>4</a> filename='torch_ep_2')
#       <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000004?line=5'>6</a> nn = agent.actor
#
# File c:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\src\agent\DDPG_Agent.py:336, in DDPG_Agent.load(self, filename, directory)
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=333'>334</a> def load(self, filename, directory):
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=334'>335</a>     self.actor.load_state_dict(
# --> <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=335'>336</a>         torch.load("%s/%s_actor.pth" % (directory, filename))
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=336'>337</a>     )
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=337'>338</a>     self.critic.load_state_dict(
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=338'>339</a>         torch.load("%s/%s_critic.pth" % (directory, filename))
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/agent/DDPG_Agent.py?line=339'>340</a>     )
#
# File c:\Users\Harold\anaconda3\lib\site-packages\torch\serialization.py:594, in load(f, map_location, pickle_module, **pickle_load_args)
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=590'>591</a> if 'encoding' not in pickle_load_args.keys():
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=591'>592</a>     pickle_load_args['encoding'] = 'utf-8'
# --> <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=593'>594</a> with _open_file_like(f, 'rb') as opened_file:
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=594'>595</a>     if _is_zipfile(opened_file):
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=595'>596</a>         # The zipfile reader is going to advance the current file position.
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=596'>597</a>         # If we want to actually tail call to torch.jit.load, we need to
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=597'>598</a>         # reset back to the original position.
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=598'>599</a>         orig_position = opened_file.tell()
#
# File c:\Users\Harold\anaconda3\lib\site-packages\torch\serialization.py:230, in _open_file_like(name_or_buffer, mode)
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=227'>228</a> def _open_file_like(name_or_buffer, mode):
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=228'>229</a>     if _is_path(name_or_buffer):
# --> <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=229'>230</a>         return _open_file(name_or_buffer, mode)
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=230'>231</a>     else:
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=231'>232</a>         if 'w' in mode:
#
# File c:\Users\Harold\anaconda3\lib\site-packages\torch\serialization.py:211, in _open_file.__init__(self, name, mode)
#     <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=209'>210</a> def __init__(self, name, mode):
# --> <a href='file:///c%3A/Users/Harold/anaconda3/lib/site-packages/torch/serialization.py?line=210'>211</a>     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Harold\\Desktop\\ENAC-Semester-Project\\DIET_Controller\\logs\\simple_simulation\\results\\DDPG_Agent\\2022_6_6\\results_2022_6_6_17_41\\model_weights/torch_ep_2_actor.pth'

# %%
a = torch.Tensor(np.array( [7.0828873 ,
 41.83974785,
  8.67061955,
 1,
  1.        ,
  0        ])).to('cuda')

b = torch.Tensor(-np.ones(6)).to('cuda')
nn(b)
# Out:
# tensor([19.0937], device='cuda:0', grad_fn=<AddBackward0>)

# %%
def mlp(sizes, activation, output_activation=nn.Identity):
    layers = []
    for j in range(len(sizes) - 1):
        act = activation if j < len(sizes) - 2 else output_activation
        layers += [nn.Linear(sizes[j], sizes[j + 1]), act()]
    return nn.Sequential(*layers)

# %%
mlp([1,128,128,1], nn.ReLU,nn.Sigmoid)(torch.as_tensor([1.0]))
# Out:
# tensor([0.5692], grad_fn=<SigmoidBackward0>)

# %%
agent.ac.q
# Out:
# MLPQFunction(
#   (q): Sequential(
#     (0): Linear(in_features=7, out_features=256, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=256, out_features=256, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Identity()
#   )
# )

# %%
from utils import all_combinations_list

best_reward = -np.inf
best_path = ""

logging_path = r"C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\logs\simple_simulation"

for curr_agent_arguments in all_combinations_list(agent_arguments):

    agent = DDPGSpinUp(env).from_dict(dict_arguments=curr_agent_arguments)
    results_path, summary_df = agent.train(logging_path= logging_path, num_episodes=2, num_iterations= None,log=True)
    total_cum_reward = cumulative_reward(summary_df)
    if total_cum_reward > best_reward:
        best_reward = total_cum_reward
        best_path = results_path
  

best_path
# Out:
# SELECTED ENV ACTION [19.86978]
# Iteration0
# SELECTED ENV ACTION [20.603329]
# Iteration1000
# SELECTED ENV ACTION [17.12208]
# Iteration2000
# SELECTED ENV ACTION [16.828764]
# Iteration3000
# SELECTED ENV ACTION [17.083227]
# Iteration4000
# SELECTED ENV ACTION [17.856403]
# Iteration5000
# SELECTED ENV ACTION [[16.0002]]
# Iteration6000
# SELECTED ENV ACTION [18.568802]
# Iteration7000
# SELECTED ENV ACTION [16.400736]
# Iteration8000
# SELECTED ENV ACTION [18.689232]
# Iteration9000
# SELECTED ENV ACTION [[16.00003]]
# Iteration10000
# SELECTED ENV ACTION [20.792124]
# Iteration11000
# SELECTED ENV ACTION [16.784826]
# Iteration12000
# SELECTED ENV ACTION [16.575214]
# Iteration13000
# SELECTED ENV ACTION [[16.00001]]
# Iteration14000
# SELECTED ENV ACTION [[16.00001]]
# Iteration15000
# SELECTED ENV ACTION [[16.000008]]
# Iteration16000
# SELECTED ENV ACTION [[16.000006]]
# Iteration17000
# SELECTED ENV ACTION [[16.000006]]
# Iteration18000
# SELECTED ENV ACTION [[16.000004]]
# Iteration19000
# SELECTED ENV ACTION [[16.000004]]
# Iteration20000
# SELECTED ENV ACTION [[16.000004]]
# Iteration21000
# Iteration0
# SELECTED ENV ACTION [[16.000004]]
# Iteration1000
# SELECTED ENV ACTION [[16.000011]]
# Iteration2000
# SELECTED ENV ACTION [[16.000004]]
# Iteration3000
# SELECTED ENV ACTION [19.428717]
# Iteration4000
# SELECTED ENV ACTION [[16.000011]]
# Iteration5000
# SELECTED ENV ACTION [[16.000011]]
# Iteration6000
# SELECTED ENV ACTION [[16.000011]]
# Iteration7000
# SELECTED ENV ACTION [[16.000011]]
# Iteration8000
# SELECTED ENV ACTION [[16.000011]]
# Iteration9000
# SELECTED ENV ACTION [17.522333]
# Iteration10000
# SELECTED ENV ACTION [[16.000004]]
# Iteration11000
# SELECTED ENV ACTION [[16.000002]]
# Iteration12000
# SELECTED ENV ACTION [[16.000002]]
# Iteration13000
# SELECTED ENV ACTION [[16.000002]]
# Iteration14000
# SELECTED ENV ACTION [[16.000002]]
# Iteration15000
# SELECTED ENV ACTION [[16.000002]]
# Iteration16000
# SELECTED ENV ACTION [[16.000002]]
# Iteration17000
# SELECTED ENV ACTION [[16.]]
# Iteration18000
# SELECTED ENV ACTION [[16.]]
# Iteration19000
# SELECTED ENV ACTION [[16.]]
# Iteration20000
# SELECTED ENV ACTION [[16.]]
# Iteration21000
# SELECTED ENV ACTION [[16.]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\src\DDPG_notebook.ipynb Cell 9' in <cell line: 8>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000007?line=9'>10</a> agent = DDPGSpinUp(env).from_dict(dict_arguments=curr_agent_arguments)
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000007?line=10'>11</a> results_path, summary_df = agent.train(logging_path= logging_path, num_episodes=2, num_iterations= None,log=True)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000007?line=11'>12</a> total_cum_reward = cumulative_reward(summary_df)
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000007?line=12'>13</a> if total_cum_reward > best_reward:
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DDPG_notebook.ipynb#ch0000007?line=13'>14</a>     best_reward = total_cum_reward
#
# NameError: name 'cumulative_reward' is not defined

# %%
from utils import assess_performance

assess_performance(r'C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_14_54/')
# Out:
# {WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_14_54/experiments_csv/experiments_results_1.csv'): 0.5350667456999525,
#  WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_14_54/experiments_csv/experiments_results_2.csv'): 0.5619388214374257,
#  WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_14_54/experiments_csv/experiments_results_summary.csv'): 0.560152310902544}

# %%
# Example of how to use the function: 

from utils import search_paths

searching_directory = r"C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller"

conditions={
    "is_test":["=",False],
    "num_iterations": ["=",21744], # to only have have trainings where the full simulation was used
    "num_episodes":["=",3],
    "alpha":["=",1],
    "beta":["=",1],
    "num_hidden_layers":[">",2]
}

path_list, best_reward_path, best_heat_path = search_paths(searching_directory,conditions=conditions, top_k=10)

best_reward_path, best_heat_path
# Out:
# (array([WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_16_20/env_params_2022_4_30_16_20.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_15_39/env_params_2022_4_30_15_39.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_16_10/env_params_2022_4_30_16_10.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_15_50/env_params_2022_4_30_15_50.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_49/env_params_2022_4_30_22_49.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_31/env_params_2022_4_30_22_31.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_18/env_params_2022_4_30_22_18.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_5_2/results_2022_5_2_21_56/env_params_2022_5_2_21_56.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_1/env_params_2022_4_30_22_1.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_5_2/results_2022_5_2_21_42/env_params_2022_5_2_21_42.json')],
#        dtype=object),
#  array([WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_5_2/results_2022_5_2_21_42/env_params_2022_5_2_21_42.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_5_2/results_2022_5_2_21_56/env_params_2022_5_2_21_56.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_1/env_params_2022_4_30_22_1.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_31/env_params_2022_4_30_22_31.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_18/env_params_2022_4_30_22_18.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_15_50/env_params_2022_4_30_15_50.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_22_49/env_params_2022_4_30_22_49.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_15_39/env_params_2022_4_30_15_39.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_16_10/env_params_2022_4_30_16_10.json'),
#         WindowsPath('C:/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/results/2022_4_30/results_2022_4_30_16_20/env_params_2022_4_30_16_20.json')],
#        dtype=object))

# %%
import pandas as pd

# %%
d = True

if(d == False):
    print("bite")

# %%
df = pd.read_csv(r"C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\results\2022_5_10\results_2022_5_10_15_0\experiments_csv\experiments_results_1.csv")

# %%
from pathlib import Path
import json

searching_directory = r"C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\results\DQN_Agent"

for path in Path(searching_directory).glob("**/*json"):
        
        if os.path.getsize(path) > 0 and str(path).__contains__("env_params"):
                f = open(path,"r")
                log_dict = json.load(f)
                closed= False
                if not("discrete_action_dim" in log_dict.keys()) or (log_dict["action_dim"] != 1):
                    print(path)
                    closed=True
                    log_dict["discrete_action_dim"] = log_dict["action_dim"]
                    log_dict["action_dim"] = 1
                    f.close()

                    os.remove(path)
                    with open(path, 'w') as f:
                        f.write(json.dumps(log_dict,indent=True))

                if not(closed):
                    f.close()

# %% [markdown]
# # Testing performance pipeline

# %%
import Performance

env = DiscreteSimpleEnvironment(param_list=['Tair', 'RH', 'Tmrt', 'Tout', 'Qheat', 'Occ'],
alpha=1,
beta=1,
min_temp=16,
max_temp=21,
discrete_action_dim=100,
modelname='CELLS_v1.fmu',
simulation_path=r'C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\EnergyPlus_simulations\simple_simulation',
days=151,
hours=24,
minutes=60,
seconds=60,
ep_timestep=6)

agent_arguments = {
"memory_size": [1000],
"batch_size": [32],
"target_update": [100],
"epsilon_decay": [1 / 20000],
"max_epsilon": [1],
"min_epsilon":  [0.0],
"gamma": [0.99],
"inside_dim": [128],
"num_hidden_layers": [1],
"seed": [778]
}


parameter = ("seed", [775,776])

logging_path = r"C:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\logs\simple_simulation"

utility_function = Performance.cumulative_reward

agent = DQNAgent(env=env)


dispersion,risk = Performance.across_runs(agent=agent, agent_arguments=agent_arguments, parameter=parameter,agent_name="DQN_Agent",
    logging_path=logging_path, num_episodes=2, num_iterations=env.numsteps, utility_function=utility_function,alpha=0.05)
# Out:
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\src\DQN_notebook.ipynb Cell 14' in <cell line: 40>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DQN_notebook.ipynb#ch0000013?line=34'>35</a> utility_function = Performance.cumulative_reward
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DQN_notebook.ipynb#ch0000013?line=36'>37</a> agent = DQNAgent(env=env)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DQN_notebook.ipynb#ch0000013?line=39'>40</a> dispersion,risk = Performance.across_runs(agent=agent, agent_arguments=agent_arguments, parameter=parameter,agent_name="DQN_Agent",
#      <a href='vscode-notebook-cell:/c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/DQN_notebook.ipynb#ch0000013?line=40'>41</a>     logging_path=logging_path, num_episodes=2, utility_function=utility_function,alpha=0.05)
#
# File c:\Users\Harold\Desktop\ENAC-Semester-Project\DIET_Controller\src\Performance.py:152, in across_runs(agent, agent_arguments, parameter, logging_path, agent_name, num_episodes, utility_function, alpha)
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=136'>137</a> cvar = CVaR(utilities_results, alpha=alpha)
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=138'>139</a> results_dict = {
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=139'>140</a>     "parameter": parameter,
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=140'>141</a>     "utility_function": utility_function.__name__,
#    (...)
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=144'>145</a>     "CVaR": cvar,
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=145'>146</a> }
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=147'>148</a> logger = Logger(
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=148'>149</a>     logging_path=logging_path,
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=149'>150</a>     agent_name=agent_name,
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=150'>151</a>     num_episodes=num_episodes,
# --> <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=151'>152</a>     num_iterations=env.numsteps,
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=152'>153</a> )
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=154'>155</a> logger.log_performance_pipeline(results_dict)
#     <a href='file:///c%3A/Users/Harold/Desktop/ENAC-Semester-Project/DIET_Controller/src/Performance.py?line=156'>157</a> return (iqr, cvar)
#
# NameError: name 'env' is not defined
