# %%
import numpy as np
from agent.DDPG_Agent import DDPG_Agent
from environment.ContinuousEnvironment import ContinuousSimpleEnvironment

import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set environment

# %%
env = ContinuousSimpleEnvironment(param_list=['Tair', 'RH', 'Tmrt', 'Tout', 'Qheat', 'Occ'],
alpha=0.25,
beta=1,
min_temp=16,
max_temp=21,
modelname='CELLS_v1.fmu',
simulation_path=r'C:\Users\hbenoit\Desktop\DIET_Controller\EnergyPlus_simulations\simple_simulation',
days=151,
hours=24,
minutes=60,
seconds=60,
ep_timestep=6)

# %% [markdown]
# ## Hyperparameter tuning and training

# %%
from Performance import all_combinations_list
from Performance import search_similar

agent_arguments = {
"discount": [0.99],
"memory_size": [1000],
"batch_size": [128],
"tau": [0.05],
"policy_noise": [0.2],
"noise_clip":[0.5],
"lr":[1e-3],
"inside_dim":[32,64,128,256],
"num_hidden_layers":[1,2,3,4],
"num_random_episodes":[1],
"num_training_iterations":[100],
"seed": [770]
}

logging_path = r"C:\Users\hbenoit\Desktop\DIET_Controller\logs\simple_simulation"
searching_directory = r"C:\Users\hbenoit\Desktop\DIET_Controller\logs\simple_simulation\DDPG_Agent\results"

for curr_agent_arguments in all_combinations_list(agent_arguments):

    ## creating the dictionary of parameters against which to check
    agent = DDPG_Agent(env).from_dict(dict_arguments=curr_agent_arguments)
    log_dict = {**agent.log_dict(), **env.log_dict()}
    num_episodes = 10
    log_dict["num_episodes"] = num_episodes

    ## so that we don't train a configuration that has already been trained
    if(not(search_similar(searching_directory, log_dict))):
        print("WE TRAIN")
        results_path, summary_df = agent.train(logging_path= logging_path,
         num_iterations= None,
         num_episodes=num_episodes,
         log=True)

# %% [markdown]
# # Finding the best performing agent in the logs

# %%
# Example of how to use the function: 
# 
import Performance

searching_directory = r"C:\Users\hbenoit\Desktop\DIET_Controller\logs\simple_simulation\DDPG_Agent"

conditions = {"seed":["=",770],    "alpha":["=",0.25],
    "beta":["=",1], "num_episodes":["=",10]}

best_path_list = Performance.search_paths(
searching_directory,
conditions=conditions,
top_k=1,
utility_function=Performance.cumulative_reward,
normalized=True)

# %%
best_path_list
# Out:
# ['C:\\Users\\hbenoit\\Desktop\\DIET_Controller\\logs\\simple_simulation\\DDPG_Agent\\results\\2022_6_19\\results_2022_6_19_6_41']

# %% [markdown]
# ## Testing in-training performance pipeline
#
# Here, we test the performance of the best agent according to the cumulative reward

# %%
from logger.SimpleLogger import SimpleLogger

best_agent_path = best_path_list[0]


parameter = ("seed", [775,776,777,778])

logging_path = r"C:\Users\hbenoit\Desktop\DIET_Controller\logs\simple_simulation"

utility_function = Performance.cumulative_reward
agent = DDPG_Agent(env=env)
num_episodes = 5
num_iterations = env.numsteps
agent_name = "DDPG_Agent"

results_dict = Performance.across_runs(
agent=agent,
agent_config_path=best_agent_path,
parameter=parameter,
num_episodes=num_episodes,
num_iterations=num_iterations,
utility_function=utility_function,
alpha=0.05,
window=6,
column_names=["Tset","Reward"])

logger = SimpleLogger(
        logging_path=logging_path,
        agent_name="DDPG_Agent",
        num_episodes=num_episodes,
        num_iterations=num_iterations,
    )

results_dict["alpha"]= agent.env.alpha
results_dict["beta"]= agent.env.beta

logger.log_performance_pipeline(results_dict,fixed_policy=False)
# Out:
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Training iterations 0
# Iteration0
# ACTION SELECTED 16.000009536743164
# Iteration1000
# ACTION SELECTED 16.000019073486328
# Iteration2000
# ACTION SELECTED 16.000001907348633
# Iteration3000
# ACTION SELECTED 16.000003814697266
# Iteration4000
# ACTION SELECTED 16.000028610229492
# Iteration5000
# ACTION SELECTED 16.00001335144043
# Iteration6000
# ACTION SELECTED 16.007890701293945
# Iteration7000
# ACTION SELECTED 16.000295639038086
# Iteration8000
# ACTION SELECTED 16.000001907348633
# Iteration9000
# ACTION SELECTED 16.000043869018555
# Iteration10000
# ACTION SELECTED 16.0
# Iteration11000
# ACTION SELECTED 16.000015258789062
# Iteration12000
# ACTION SELECTED 16.000024795532227
# Iteration13000
# ACTION SELECTED 16.0
# Iteration14000
# ACTION SELECTED 16.000036239624023
# Iteration15000
# ACTION SELECTED 16.0
# Iteration16000
# ACTION SELECTED 16.000009536743164
# Iteration17000
# ACTION SELECTED 16.000017166137695
# Iteration18000
# ACTION SELECTED 16.0
# Iteration19000
# ACTION SELECTED 16.0000057220459
# Iteration20000
# ACTION SELECTED 16.0
# Iteration21000
# ACTION SELECTED 16.0
# Training iterations 0
# Iteration0
# ACTION SELECTED 16.000001907348633
# Iteration1000
# ACTION SELECTED 16.000003814697266
# Iteration2000
# ACTION SELECTED 16.0
# Iteration3000
# ACTION SELECTED 16.0
# Iteration4000
# ACTION SELECTED 16.00000762939453
# Iteration5000
# ACTION SELECTED 16.000001907348633
# Iteration6000
# ACTION SELECTED 16.00212860107422
# Iteration7000
# ACTION SELECTED 16.00006103515625
# Iteration8000
# ACTION SELECTED 16.0
# Iteration9000
# ACTION SELECTED 16.000009536743164
# Iteration10000
# ACTION SELECTED 16.0
# Iteration11000
# ACTION SELECTED 16.000001907348633
# Iteration12000
# ACTION SELECTED 16.0000057220459
# Iteration13000
# ACTION SELECTED 16.0
# Iteration14000
# ACTION SELECTED 16.00000762939453
# Iteration15000
# ACTION SELECTED 16.0
# Iteration16000
# ACTION SELECTED 16.000001907348633
# Iteration17000
# ACTION SELECTED 16.000001907348633
# Iteration18000
# ACTION SELECTED 16.0
# Iteration19000
# ACTION SELECTED 16.0
# Iteration20000
# ACTION SELECTED 16.0
# Iteration21000
# ACTION SELECTED 16.0
# Training iterations 0
# Iteration0
# ACTION SELECTED 16.0
# Iteration1000
# ACTION SELECTED 16.000001907348633
# Iteration2000
# ACTION SELECTED 16.0
# Iteration3000
# ACTION SELECTED 16.0
# Iteration4000
# ACTION SELECTED 16.000001907348633
# Iteration5000
# ACTION SELECTED 16.0
# Iteration6000
# ACTION SELECTED 16.000972747802734
# Iteration7000
# ACTION SELECTED 16.000022888183594
# Iteration8000
# ACTION SELECTED 16.0
# Iteration9000
# ACTION SELECTED 16.000003814697266
# Iteration10000
# ACTION SELECTED 16.0
# Iteration11000
# ACTION SELECTED 16.000001907348633
# Iteration12000
# ACTION SELECTED 16.000001907348633
# Iteration13000
# ACTION SELECTED 16.0
# Iteration14000
# ACTION SELECTED 16.000003814697266
# Iteration15000
# ACTION SELECTED 16.0
# Iteration16000
# ACTION SELECTED 16.0
# Iteration17000
# ACTION SELECTED 16.0
# Iteration18000
# ACTION SELECTED 16.0
# Iteration19000
# ACTION SELECTED 16.0
# Iteration20000
# ACTION SELECTED 16.0
# Iteration21000
# ACTION SELECTED 16.0
# Training iterations 0
# Iteration0
# ACTION SELECTED 16.0
# Iteration1000
# ACTION SELECTED 16.0
# Iteration2000
# ACTION SELECTED 16.0
# Iteration3000
# ACTION SELECTED 16.0
# Iteration4000
# ACTION SELECTED 16.000001907348633
# Iteration5000
# ACTION SELECTED 16.0
# Iteration6000
# ACTION SELECTED 16.000507354736328
# Iteration7000
# ACTION SELECTED 16.000009536743164
# Iteration8000
# ACTION SELECTED 16.0
# Iteration9000
# ACTION SELECTED 16.000001907348633
# Iteration10000
# ACTION SELECTED 16.0
# Iteration11000
# ACTION SELECTED 16.0
# Iteration12000
# ACTION SELECTED 16.0
# Iteration13000
# ACTION SELECTED 16.0
# Iteration14000
# ACTION SELECTED 16.000001907348633
# Iteration15000
# ACTION SELECTED 16.0
# Iteration16000
# ACTION SELECTED 16.0
# Iteration17000
# ACTION SELECTED 16.0
# Iteration18000
# ACTION SELECTED 16.0
# Iteration19000
# ACTION SELECTED 16.0
# Iteration20000
# ACTION SELECTED 16.0
# Iteration21000
# ACTION SELECTED 16.0
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.99032974243164
# Iteration1000
# ACTION SELECTED 20.993946075439453
# Iteration2000
# ACTION SELECTED 20.99676513671875
# Iteration3000
# ACTION SELECTED 20.995140075683594
# Iteration4000
# ACTION SELECTED 20.99057388305664
# Iteration5000
# ACTION SELECTED 20.993928909301758
# Iteration6000
# ACTION SELECTED 20.995683670043945
# Iteration7000
# ACTION SELECTED 20.997432708740234
# Iteration8000
# ACTION SELECTED 20.997570037841797
# Iteration9000
# ACTION SELECTED 20.99526596069336
# Iteration10000
# ACTION SELECTED 20.997600555419922
# Iteration11000
# ACTION SELECTED 20.997039794921875
# Iteration12000
# ACTION SELECTED 20.994468688964844
# Iteration13000
# ACTION SELECTED 20.99760627746582
# Iteration14000
# ACTION SELECTED 20.9942626953125
# Iteration15000
# ACTION SELECTED 20.998435974121094
# Iteration16000
# ACTION SELECTED 20.998727798461914
# Iteration17000
# ACTION SELECTED 20.99863624572754
# Iteration18000
# ACTION SELECTED 20.99953269958496
# Iteration19000
# ACTION SELECTED 20.99938201904297
# Iteration20000
# ACTION SELECTED 20.999631881713867
# Iteration21000
# ACTION SELECTED 20.999841690063477
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.992412567138672
# Iteration1000
# ACTION SELECTED 20.995182037353516
# Iteration2000
# ACTION SELECTED 20.9975528717041
# Iteration3000
# ACTION SELECTED 20.996232986450195
# Iteration4000
# ACTION SELECTED 20.99246597290039
# Iteration5000
# ACTION SELECTED 20.995304107666016
# Iteration6000
# ACTION SELECTED 20.99643325805664
# Iteration7000
# ACTION SELECTED 20.997962951660156
# Iteration8000
# ACTION SELECTED 20.99816131591797
# Iteration9000
# ACTION SELECTED 20.996295928955078
# Iteration10000
# ACTION SELECTED 20.998207092285156
# Iteration11000
# ACTION SELECTED 20.997743606567383
# Iteration12000
# ACTION SELECTED 20.995656967163086
# Iteration13000
# ACTION SELECTED 20.998207092285156
# Iteration14000
# ACTION SELECTED 20.995437622070312
# Iteration15000
# ACTION SELECTED 20.998851776123047
# Iteration16000
# ACTION SELECTED 20.999053955078125
# Iteration17000
# ACTION SELECTED 20.998992919921875
# Iteration18000
# ACTION SELECTED 20.999677658081055
# Iteration19000
# ACTION SELECTED 20.999553680419922
# Iteration20000
# ACTION SELECTED 20.999744415283203
# Iteration21000
# ACTION SELECTED 20.999893188476562
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.992767333984375
# Iteration1000
# ACTION SELECTED 20.99538803100586
# Iteration2000
# ACTION SELECTED 20.997678756713867
# Iteration3000
# ACTION SELECTED 20.996408462524414
# Iteration4000
# ACTION SELECTED 20.992794036865234
# Iteration5000
# ACTION SELECTED 20.995548248291016
# Iteration6000
# ACTION SELECTED 20.996562957763672
# Iteration7000
# ACTION SELECTED 20.9980525970459
# Iteration8000
# ACTION SELECTED 20.99825668334961
# Iteration9000
# ACTION SELECTED 20.996477127075195
# Iteration10000
# ACTION SELECTED 20.998306274414062
# Iteration11000
# ACTION SELECTED 20.99786376953125
# Iteration12000
# ACTION SELECTED 20.995861053466797
# Iteration13000
# ACTION SELECTED 20.998306274414062
# Iteration14000
# ACTION SELECTED 20.995634078979492
# Iteration15000
# ACTION SELECTED 20.998920440673828
# Iteration16000
# ACTION SELECTED 20.999107360839844
# Iteration17000
# ACTION SELECTED 20.99905014038086
# Iteration18000
# ACTION SELECTED 20.99970054626465
# Iteration19000
# ACTION SELECTED 20.999584197998047
# Iteration20000
# ACTION SELECTED 20.99976348876953
# Iteration21000
# ACTION SELECTED 20.999900817871094
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.992815017700195
# Iteration1000
# ACTION SELECTED 20.995424270629883
# Iteration2000
# ACTION SELECTED 20.99770164489746
# Iteration3000
# ACTION SELECTED 20.996442794799805
# Iteration4000
# ACTION SELECTED 20.992843627929688
# Iteration5000
# ACTION SELECTED 20.995586395263672
# Iteration6000
# ACTION SELECTED 20.996591567993164
# Iteration7000
# ACTION SELECTED 20.99807357788086
# Iteration8000
# ACTION SELECTED 20.998275756835938
# Iteration9000
# ACTION SELECTED 20.99650764465332
# Iteration10000
# ACTION SELECTED 20.998327255249023
# Iteration11000
# ACTION SELECTED 20.997888565063477
# Iteration12000
# ACTION SELECTED 20.995893478393555
# Iteration13000
# ACTION SELECTED 20.998323440551758
# Iteration14000
# ACTION SELECTED 20.99566650390625
# Iteration15000
# ACTION SELECTED 20.998931884765625
# Iteration16000
# ACTION SELECTED 20.999116897583008
# Iteration17000
# ACTION SELECTED 20.999061584472656
# Iteration18000
# ACTION SELECTED 20.999704360961914
# Iteration19000
# ACTION SELECTED 20.999588012695312
# Iteration20000
# ACTION SELECTED 20.999767303466797
# Iteration21000
# ACTION SELECTED 20.999902725219727
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.98396110534668
# Iteration1000
# ACTION SELECTED 20.99567413330078
# Iteration2000
# ACTION SELECTED 20.99932861328125
# Iteration3000
# ACTION SELECTED 20.99749755859375
# Iteration4000
# ACTION SELECTED 20.995899200439453
# Iteration5000
# ACTION SELECTED 20.998998641967773
# Iteration6000
# ACTION SELECTED 20.998363494873047
# Iteration7000
# ACTION SELECTED 20.999765396118164
# Iteration8000
# ACTION SELECTED 20.99959945678711
# Iteration9000
# ACTION SELECTED 20.999387741088867
# Iteration10000
# ACTION SELECTED 20.999662399291992
# Iteration11000
# ACTION SELECTED 20.99969482421875
# Iteration12000
# ACTION SELECTED 20.998859405517578
# Iteration13000
# ACTION SELECTED 20.999656677246094
# Iteration14000
# ACTION SELECTED 20.99854850769043
# Iteration15000
# ACTION SELECTED 20.99984359741211
# Iteration16000
# ACTION SELECTED 20.999916076660156
# Iteration17000
# ACTION SELECTED 20.999897003173828
# Iteration18000
# ACTION SELECTED 20.999971389770508
# Iteration19000
# ACTION SELECTED 20.999977111816406
# Iteration20000
# ACTION SELECTED 20.999990463256836
# Iteration21000
# ACTION SELECTED 20.999996185302734
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999340057373047
# Iteration1000
# ACTION SELECTED 20.999774932861328
# Iteration2000
# ACTION SELECTED 20.999980926513672
# Iteration3000
# ACTION SELECTED 20.999919891357422
# Iteration4000
# ACTION SELECTED 20.99982261657715
# Iteration5000
# ACTION SELECTED 20.999971389770508
# Iteration6000
# ACTION SELECTED 20.999921798706055
# Iteration7000
# ACTION SELECTED 20.999988555908203
# Iteration8000
# ACTION SELECTED 20.999988555908203
# Iteration9000
# ACTION SELECTED 20.999975204467773
# Iteration10000
# ACTION SELECTED 20.99999237060547
# Iteration11000
# ACTION SELECTED 20.999990463256836
# Iteration12000
# ACTION SELECTED 20.99994659423828
# Iteration13000
# ACTION SELECTED 20.99999237060547
# Iteration14000
# ACTION SELECTED 20.999908447265625
# Iteration15000
# ACTION SELECTED 20.999996185302734
# Iteration16000
# ACTION SELECTED 20.999998092651367
# Iteration17000
# ACTION SELECTED 20.999998092651367
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999330520629883
# Iteration1000
# ACTION SELECTED 20.999767303466797
# Iteration2000
# ACTION SELECTED 20.999980926513672
# Iteration3000
# ACTION SELECTED 20.999916076660156
# Iteration4000
# ACTION SELECTED 20.99981689453125
# Iteration5000
# ACTION SELECTED 20.999971389770508
# Iteration6000
# ACTION SELECTED 20.999916076660156
# Iteration7000
# ACTION SELECTED 20.999988555908203
# Iteration8000
# ACTION SELECTED 20.999988555908203
# Iteration9000
# ACTION SELECTED 20.99997329711914
# Iteration10000
# ACTION SELECTED 20.99999237060547
# Iteration11000
# ACTION SELECTED 20.999990463256836
# Iteration12000
# ACTION SELECTED 20.999942779541016
# Iteration13000
# ACTION SELECTED 20.99999237060547
# Iteration14000
# ACTION SELECTED 20.99990463256836
# Iteration15000
# ACTION SELECTED 20.999996185302734
# Iteration16000
# ACTION SELECTED 20.999998092651367
# Iteration17000
# ACTION SELECTED 20.999996185302734
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999303817749023
# Iteration1000
# ACTION SELECTED 20.9997501373291
# Iteration2000
# ACTION SELECTED 20.999980926513672
# Iteration3000
# ACTION SELECTED 20.99991226196289
# Iteration4000
# ACTION SELECTED 20.99980354309082
# Iteration5000
# ACTION SELECTED 20.999969482421875
# Iteration6000
# ACTION SELECTED 20.999908447265625
# Iteration7000
# ACTION SELECTED 20.999988555908203
# Iteration8000
# ACTION SELECTED 20.999988555908203
# Iteration9000
# ACTION SELECTED 20.999971389770508
# Iteration10000
# ACTION SELECTED 20.99999237060547
# Iteration11000
# ACTION SELECTED 20.999988555908203
# Iteration12000
# ACTION SELECTED 20.99993896484375
# Iteration13000
# ACTION SELECTED 20.999990463256836
# Iteration14000
# ACTION SELECTED 20.999897003173828
# Iteration15000
# ACTION SELECTED 20.999996185302734
# Iteration16000
# ACTION SELECTED 20.999998092651367
# Iteration17000
# ACTION SELECTED 20.999996185302734
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# Iteration1000
# Iteration2000
# Iteration3000
# Iteration4000
# Iteration5000
# Iteration6000
# Iteration7000
# Iteration8000
# Iteration9000
# Iteration10000
# Iteration11000
# Iteration12000
# Iteration13000
# Iteration14000
# Iteration15000
# Iteration16000
# Iteration17000
# Iteration18000
# Iteration19000
# Iteration20000
# Iteration21000
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999122619628906
# Iteration1000
# ACTION SELECTED 20.999277114868164
# Iteration2000
# ACTION SELECTED 20.999717712402344
# Iteration3000
# ACTION SELECTED 20.999515533447266
# Iteration4000
# ACTION SELECTED 20.99860382080078
# Iteration5000
# ACTION SELECTED 20.999134063720703
# Iteration6000
# ACTION SELECTED 20.985692977905273
# Iteration7000
# ACTION SELECTED 20.998289108276367
# Iteration8000
# ACTION SELECTED 20.9997615814209
# Iteration9000
# ACTION SELECTED 20.99881362915039
# Iteration10000
# ACTION SELECTED 20.99980926513672
# Iteration11000
# ACTION SELECTED 20.999467849731445
# Iteration12000
# ACTION SELECTED 20.999216079711914
# Iteration13000
# ACTION SELECTED 20.99980926513672
# Iteration14000
# ACTION SELECTED 20.99924087524414
# Iteration15000
# ACTION SELECTED 20.999879837036133
# Iteration16000
# ACTION SELECTED 20.999780654907227
# Iteration17000
# ACTION SELECTED 20.999801635742188
# Iteration18000
# ACTION SELECTED 20.999982833862305
# Iteration19000
# ACTION SELECTED 20.999876022338867
# Iteration20000
# ACTION SELECTED 20.999954223632812
# Iteration21000
# ACTION SELECTED 20.999984741210938
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999353408813477
# Iteration1000
# ACTION SELECTED 20.999488830566406
# Iteration2000
# ACTION SELECTED 20.999820709228516
# Iteration3000
# ACTION SELECTED 20.999671936035156
# Iteration4000
# ACTION SELECTED 20.99903106689453
# Iteration5000
# ACTION SELECTED 20.99945068359375
# Iteration6000
# ACTION SELECTED 20.99233627319336
# Iteration7000
# ACTION SELECTED 20.99899673461914
# Iteration8000
# ACTION SELECTED 20.99985122680664
# Iteration9000
# ACTION SELECTED 20.999271392822266
# Iteration10000
# ACTION SELECTED 20.999881744384766
# Iteration11000
# ACTION SELECTED 20.999679565429688
# Iteration12000
# ACTION SELECTED 20.999481201171875
# Iteration13000
# ACTION SELECTED 20.999881744384766
# Iteration14000
# ACTION SELECTED 20.999492645263672
# Iteration15000
# ACTION SELECTED 20.999927520751953
# Iteration16000
# ACTION SELECTED 20.9998779296875
# Iteration17000
# ACTION SELECTED 20.999887466430664
# Iteration18000
# ACTION SELECTED 20.999990463256836
# Iteration19000
# ACTION SELECTED 20.999935150146484
# Iteration20000
# ACTION SELECTED 20.999977111816406
# Iteration21000
# ACTION SELECTED 20.99999237060547
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999452590942383
# Iteration1000
# ACTION SELECTED 20.999582290649414
# Iteration2000
# ACTION SELECTED 20.999862670898438
# Iteration3000
# ACTION SELECTED 20.999736785888672
# Iteration4000
# ACTION SELECTED 20.99921417236328
# Iteration5000
# ACTION SELECTED 20.99958038330078
# Iteration6000
# ACTION SELECTED 20.995214462280273
# Iteration7000
# ACTION SELECTED 20.999330520629883
# Iteration8000
# ACTION SELECTED 20.999887466430664
# Iteration9000
# ACTION SELECTED 20.999454498291016
# Iteration10000
# ACTION SELECTED 20.99991226196289
# Iteration11000
# ACTION SELECTED 20.999765396118164
# Iteration12000
# ACTION SELECTED 20.99959945678711
# Iteration13000
# ACTION SELECTED 20.99991226196289
# Iteration14000
# ACTION SELECTED 20.99959945678711
# Iteration15000
# ACTION SELECTED 20.99994659423828
# Iteration16000
# ACTION SELECTED 20.999914169311523
# Iteration17000
# ACTION SELECTED 20.999919891357422
# Iteration18000
# ACTION SELECTED 20.99999237060547
# Iteration19000
# ACTION SELECTED 20.999958038330078
# Iteration20000
# ACTION SELECTED 20.999984741210938
# Iteration21000
# ACTION SELECTED 20.999996185302734
# Training iterations 0
# Iteration0
# ACTION SELECTED 20.999387741088867
# Iteration1000
# ACTION SELECTED 20.999553680419922
# Iteration2000
# ACTION SELECTED 20.99985694885254
# Iteration3000
# ACTION SELECTED 20.999717712402344
# Iteration4000
# ACTION SELECTED 20.99917984008789
# Iteration5000
# ACTION SELECTED 20.999576568603516
# Iteration6000
# ACTION SELECTED 20.99677848815918
# Iteration7000
# ACTION SELECTED 20.999454498291016
# Iteration8000
# ACTION SELECTED 20.9998836517334
# Iteration9000
# ACTION SELECTED 20.99945831298828
# Iteration10000
# ACTION SELECTED 20.999908447265625
# Iteration11000
# ACTION SELECTED 20.999767303466797
# Iteration12000
# ACTION SELECTED 20.999588012695312
# Iteration13000
# ACTION SELECTED 20.999908447265625
# Iteration14000
# ACTION SELECTED 20.999584197998047
# Iteration15000
# ACTION SELECTED 20.99994659423828
# Iteration16000
# ACTION SELECTED 20.999916076660156
# Iteration17000
# ACTION SELECTED 20.999919891357422
# Iteration18000
# ACTION SELECTED 20.99999237060547
# Iteration19000
# ACTION SELECTED 20.999958038330078
# Iteration20000
# ACTION SELECTED 20.999984741210938
# Iteration21000
# ACTION SELECTED 20.999996185302734

# %% [markdown]
# ## Testing fixed policy performance
#
# Here, we test the performance of the best agent according to the cumulative reward

# %%
from logger.SimpleLogger import SimpleLogger

best_agent_path = best_path_list[0]



utility_function = Performance.cumulative_reward
agent = DDPG_Agent(env=env)
num_testing = 3
num_episodes = 5
num_iterations = env.numsteps
agent_name = "DDPG_Agent"

results_dict = Performance.across_fixed_policy(
agent=agent,
agent_config_path=best_agent_path,
num_testing=num_testing,
num_episodes=num_episodes,
num_iterations=num_iterations,
utility_function=utility_function,
alpha=0.05,
window=6,
column_names=["Tset","Reward"])

logging_path = r"C:\Users\hbenoit\Desktop\DIET_Controller\logs\simple_simulation"

logger = SimpleLogger(
        logging_path=logging_path,
        agent_name="DDPG_Agent",
        num_episodes=num_episodes,
        num_iterations=num_iterations,
    )

results_dict["alpha"]= agent.env.alpha
results_dict["beta"]= agent.env.beta

logger.log_performance_pipeline(
results_dict,
fixed_policy=True)
# Out:
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
# Iteration0
# ACTION SELECTED 21.0
# Iteration1000
# ACTION SELECTED 20.999996185302734
# Iteration2000
# ACTION SELECTED 21.0
# Iteration3000
# ACTION SELECTED 21.0
# Iteration4000
# ACTION SELECTED 20.999996185302734
# Iteration5000
# ACTION SELECTED 21.0
# Iteration6000
# ACTION SELECTED 20.99999237060547
# Iteration7000
# ACTION SELECTED 21.0
# Iteration8000
# ACTION SELECTED 21.0
# Iteration9000
# ACTION SELECTED 21.0
# Iteration10000
# ACTION SELECTED 21.0
# Iteration11000
# ACTION SELECTED 21.0
# Iteration12000
# ACTION SELECTED 21.0
# Iteration13000
# ACTION SELECTED 21.0
# Iteration14000
# ACTION SELECTED 20.999996185302734
# Iteration15000
# ACTION SELECTED 21.0
# Iteration16000
# ACTION SELECTED 21.0
# Iteration17000
# ACTION SELECTED 21.0
# Iteration18000
# ACTION SELECTED 21.0
# Iteration19000
# ACTION SELECTED 21.0
# Iteration20000
# ACTION SELECTED 21.0
# Iteration21000
# ACTION SELECTED 21.0
